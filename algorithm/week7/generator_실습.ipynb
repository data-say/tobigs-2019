# %%
from __future__ import division
import os
import psutil
import random
import time
import warnings
warnings.filterwarnings('ignore')

# %%
names = ['김유민', '김탁영', '이승현', '이영전', '임채빈', '김태한']
majors = ['컴공', '경영', '영문', '수학', '기계']

# %%
#메모리확인위해
process = psutil.Process(os.getpid())
mem_before = process.memory_info().rss / 1024 / 1024

# %%
#일반함수
def people_list(num_people):
    result = []
    for i in range(num_people):
        person = {
            'id': i,
            'name': random.choice(names),
            'major': random.choice(majors)
        }
        result.append(person)
    return result

# %%
#generator
def people_generator(num_people):
    for i in range(num_people):
        person = {
            'id': i,
            'name': random.choice(names),
            'major': random.choice(majors)
        }
        yield person

# %%
t1 = time.clock()
people = people_list(1000000)  #1 people_list를 호출
t2 = time.clock()

# %%
mem_after = process.memory_info().rss / 1024 / 1024
total_time = t2 - t1

# %%
print('시작 전 메모리 사용량: {} MB'.format(mem_before))
print('종료 후 메모리 사용량: {} MB'.format(mem_after))
print('총 소요된 시간: {:.6f} 초'.format(total_time))
# Out:
# 시작 전 메모리 사용량: 59.828125 MB
# 종료 후 메모리 사용량: 331.1796875 MB
# 총 소요된 시간: 6.998574 초

# %%
t1 = time.clock()
people = people_generator(1000000)  #1 people_generator를 호출
t2 = time.clock()

# %%
mem_after = process.memory_info().rss / 1024 / 1024
total_time = t2 - t1

# %%
print('시작 전 메모리 사용량: {} MB'.format(mem_before))
print('종료 후 메모리 사용량: {} MB'.format(mem_after))
print('총 소요된 시간: {:.6f} 초'.format(total_time))
# Out:
# 시작 전 메모리 사용량: 59.828125 MB
# 종료 후 메모리 사용량: 60.6484375 MB
# 총 소요된 시간: 0.339919 초
