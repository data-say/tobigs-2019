# %%
from IPython.display import Image

Image(filename='Moneyball_Explanation.png')

# %%
Image(filename='Moneyball_Explanation1.png')

# %%
Image(filename='Moneyball_Explanation2.png')

# %%
Image(filename='Moneyball_Explanation3.png')

# %%
Image(filename='Moneyball_Explanation4.png')
